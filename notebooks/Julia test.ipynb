# %%
using Pkg
Pkg.add("PyPlot")
import PyPlot
# Out:
#     Updating registry at `/opt/julia/registries/General`
#    Resolving package versions...
#    Installed PyPlot ──────────── v2.10.0
#    Installed LaTeXStrings ────── v1.3.0
#    Installed Reexport ────────── v1.2.2
#    Installed FixedPointNumbers ─ v0.8.4
#    Installed ColorTypes ──────── v0.11.0
#    Installed MacroTools ──────── v0.5.9
#    Installed Colors ──────────── v0.12.8
#    Installed PyCall ──────────── v1.93.0
#     Updating `/opt/julia/environments/v1.6/Project.toml`
#   [d330b81b] + PyPlot v2.10.0
#     Updating `/opt/julia/environments/v1.6/Manifest.toml`
#   [3da002f7] + ColorTypes v0.11.0
#   [5ae59095] + Colors v0.12.8
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [b964fa9f] + LaTeXStrings v1.3.0
#   [1914dd2f] + MacroTools v0.5.9
#   [438e738f] + PyCall v1.93.0
#   [d330b81b] + PyPlot v2.10.0
#   [189a3867] + Reexport v1.2.2
# ...

# %%
x = range(0, stop=2pi, length=200)
y = sin.(x)
PyPlot.plot(x, y);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
n = 100
f(x) = x^2

x = randn(n)
PyPlot.plot(f.(x), label="x^2")
PyPlot.plot(x, label="x")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f51593074c0>
